# %%
import pandas as pd

df_chembl = pd.read_csv('/rds-d2/user/wjm41/hpc-work/datasets/Ugis/datasets/chembl_d4_ligands.csv', delimiter=';')

print(df_chembl)
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0             CHEMBL633    AMIODARONE                   4            645.32
# 1          CHEMBL267930     SPIPERONE                   0            395.48
# 2            CHEMBL1113     AMOXAPINE                   4            313.79
# 3          CHEMBL241436           NaN                   0            506.48
# 4          CHEMBL392437           NaN                   0            430.38
# ...                 ...           ...                 ...               ...
# 3175           CHEMBL42     CLOZAPINE                   4            326.83
# 3176           CHEMBL42     CLOZAPINE                   4            326.83
# 3177           CHEMBL42     CLOZAPINE                   4            326.83
# 3178        CHEMBL59725           NaN                   0            462.45
# 3179           CHEMBL42     CLOZAPINE                   4            326.83
#
#      #RO5 Violations AlogP Compound Key  \
# ...

# %%
assay_type = df_chembl['Standard Type'].value_counts()
assay_type
# Out:
# Ki      2865
# IC50     252
# EC50      55
# Kd         8
# Name: Standard Type, dtype: int64

# %%
assay_label = df_chembl['BAO Label'].value_counts()
assay_label
# Out:
# cell-based format        2062
# single protein format    1055
# cell membrane format       38
# assay format               24
# organism-based format       1
# Name: BAO Label, dtype: int64

# %%
assay_types = df_chembl['Assay Description'].value_counts()
print(assay_types)
assay_types.hist()
# Out:
# Displacement of [3H]-Spiperone from human recombinant dopamine D4 receptor expressed in CHOK1 cells                                                                                   102
# Displacement of [3H]spiperone from human D4.4 receptor expressed in CHO cells                                                                                                          66
# Displacement of [3H]spiperone from human dopamine D4.4 expressed in CHO cell membrane                                                                                                  65
# Displacement of [3H]-N-methylspiperone from recombinant human D4 receptor stably expressed in HEK cell membranes measured after 90 mins by microbeta scintillation counting method     51
# Inhibition of human dopamine D4 receptor                                                                                                                                               50
# ...

# %%
df_selection = df_chembl[(df_chembl['Standard Type'] == 'Ki') & (
    df_chembl['BAO Label'] == 'cell-based format') & (df_chembl['Assay Cell Type'].str.contains('CHO'))]
df_selection.sort_values(by='Document ChEMBL ID')
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 1660       CHEMBL276500           NaN                   0            219.33
# 712            CHEMBL54   HALOPERIDOL                   4            375.87
# 1670       CHEMBL278751           NaN                   0            275.44
# 1459        CHEMBL27441           NaN                   0            233.35
# 1990       CHEMBL433002           NaN                   0            285.43
# ...                 ...           ...                 ...               ...
# 2563      CHEMBL4460743           NaN                   0            503.65
# 1257      CHEMBL4589982           NaN                   0            496.03
# 2562      CHEMBL4475042           NaN                   0            542.51
# 3046      CHEMBL4544086           NaN                   0            491.61
# 1379      CHEMBL4434714           NaN                   0            521.64
#
#      #RO5 Violations AlogP      Compound Key  \
# ...

# %%
df_selection['Document ChEMBL ID'].value_counts()
# Out:
# CHEMBL1141401    65
# CHEMBL3792377    51
# CHEMBL4321823    39
# CHEMBL1135103    31
# CHEMBL1136241    30
#                  ..
# CHEMBL1144878     1
# CHEMBL1148321     1
# CHEMBL1130268     1
# CHEMBL1151947     1
# CHEMBL2390918     1
# Name: Document ChEMBL ID, Length: 89, dtype: int64

# %%
df_selection[df_selection['Document ChEMBL ID'] == 'CHEMBL1141401']
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 370        CHEMBL221549           NaN                   0            431.96
# 371        CHEMBL310843           NaN                   0            326.83
# 372        CHEMBL208018           NaN                   0            332.45
# 373        CHEMBL221640           NaN                   0            461.57
# 374        CHEMBL376445           NaN                   0            525.27
# ...                 ...           ...                 ...               ...
# 2655       CHEMBL357684           NaN                   0            393.49
# 2656       CHEMBL386986           NaN                   0            569.55
# 2661       CHEMBL221843           NaN                   0            462.60
# 3110        CHEMBL25236        BP-897                   0            417.55
# 3151       CHEMBL437490           NaN                   0            336.41
#
#      #RO5 Violations AlogP  Compound Key  \
# ...

# %%
import mols2grid

mols2grid.display(
    df_selection[df_selection['Document ChEMBL ID'] == 'CHEMBL1141401'], smiles_col='Smiles', subset=['img'], size=(250,250))
# Out:
# <iframe class="mols2grid-iframe" frameborder="0" width=100%
#
# height="0"
# onload="javascript:(function(o){o.style.height=o.contentWindow.document.body.scrollHeight+18+'px';}(this));"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 1270px;
#     width: 1270px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 250px;
#     width: 250px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# #mols2grid .data {
#     overflow: hidden;
#     white-space: nowrap;
# ...
