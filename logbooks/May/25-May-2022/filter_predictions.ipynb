# %% [markdown]
# # Filter predictions
#
# 26th May - apply structural fiilters to isocyanide ugi predictions to remove greaseballs etc

# %%
import pandas as pd
from useful_rdkit_utils import add_molecule_and_errors

df_isocyanides = pd.read_csv('/rds-d2/user/wjm41/hpc-work/datasets/Ugis/datasets/enamine_library_generation/enumerated_isocyanides_scored.csv')
add_molecule_and_errors(df_isocyanides, 'ugi', mol_col_name='mol')
# Out:
# INFO:rdkit:Enabling RDKit 2021.09.4 jupyter extensions
# 100%|██████████| 62811/62811 [00:28<00:00, 2231.19it/s]
# 100%|██████████| 62811/62811 [03:53<00:00, 269.24it/s]
# 100%|██████████| 62811/62811 [00:28<00:00, 2222.81it/s]
# 100%|██████████| 62811/62811 [00:03<00:00, 17578.14it/s]
# 100%|██████████| 62811/62811 [00:03<00:00, 17158.01it/s]
# 100%|██████████| 62811/62811 [00:24<00:00, 2562.53it/s]

# %%
from tqdm import tqdm

from dock2hit.filters import return_pains_lib, return_alert_substructs
from dock2hit.filters import does_mol_have_more_than_one_chiral_center, does_mol_have_structural_alert, does_mol_have_too_many_donors_and_acceptors, does_mol_match_pains, does_mol_satisfy_ro5

pains_lib = return_pains_lib()
alert_substructs = return_alert_substructs()

tqdm.pandas()
df_isocyanides['has_structural_alert'] = df_isocyanides['mol'].progress_apply(does_mol_have_structural_alert, 
                                                                     alert_substructs=alert_substructs)
df_isocyanides['matches_pain'] = df_isocyanides['mol'].progress_apply(
    does_mol_match_pains, pains_lib=pains_lib)
df_isocyanides['more_than_one_chiral_center'] = df_isocyanides['mol'].progress_apply(
    does_mol_have_more_than_one_chiral_center)
df_isocyanides['too_many_pcores'] = df_isocyanides['mol'].progress_apply(does_mol_have_too_many_donors_and_acceptors)
df_isocyanides['satisfies_ro5'] = df_isocyanides['mol'].progress_apply(
    does_mol_satisfy_ro5)

df_filtered = df_isocyanides.query(
    'satisfies_ro5 & ~too_many_pcores & ~matches_pain & ~more_than_one_chiral_center & ~has_structural_alert')
df_filtered
# Out:
#                    ID                          SMILES  \
# 8         EN300-75265                     CCNc1ccncc1
# 11        EN300-19067                   COc1cccc(N)c1
# 38        EN300-20183                  N#Cc1cccc(N)c1
# 85       EN300-180531                  CCC(C)(C)CN.Cl
# 105       EN300-54456                   NCCc1ccc[nH]1
# ...               ...                             ...
# 61887    EN300-238018                c1cc2c(cn1)CCCN2
# 61899  EN300-27100943  O=C(O)C(F)(F)F.O=C1CC2(CNC2)N1
# 61913   EN300-7427792             Cl.c1cc2c(cn1)NCCC2
# 61914   EN300-4299857                c1cc2c(cn1)NCCC2
# 62482  EN300-37300025             C1=CC2(C1)CCNCC2.Cl
#
#                                                      ugi  predicted_pIC50  \
# 8      CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.494262
# 11     COc1cccc(NC(=O)C(c2cccnc2)N(C(=O)c2cocn2)c2ccc...         5.476997
# 38     CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)Nc2cccc(C#N)...         5.420334
# 85     CCC(C)(C)CNC(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1cc...         5.379709
# 105    CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)NCCc2ccc[nH]...         5.370107
# ...                                                  ...              ...
# 61887  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N2CCCc3cnccc...         4.188120
# 61899  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N2CC3(CC(=O)...         4.187679
# 61913  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N2CCCc3ccncc...         4.187255
# 61914  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N2CCCc3ccncc...         4.187255
# 62482  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N2CCC3(C=CC3...         4.164251
#
#                                                     mol Error  \
# 8      <rdkit.Chem.rdchem.Mol object at 0x151acd92a5e0>
# 11     <rdkit.Chem.rdchem.Mol object at 0x151acd92a9a0>
# 38     <rdkit.Chem.rdchem.Mol object at 0x151acd1f8400>
# 85     <rdkit.Chem.rdchem.Mol object at 0x151acd1f95e0>
# 105    <rdkit.Chem.rdchem.Mol object at 0x151acd1f9d60>
# ...                                                 ...   ...
# 61887  <rdkit.Chem.rdchem.Mol object at 0x151ace60d8e0>
# 61899  <rdkit.Chem.rdchem.Mol object at 0x151ace60dd60>
# 61913  <rdkit.Chem.rdchem.Mol object at 0x151ace60f2e0>
# 61914  <rdkit.Chem.rdchem.Mol object at 0x151ace60f340>
# 62482  <rdkit.Chem.rdchem.Mol object at 0x151ace625b80>
#
#        has_structural_alert  matches_pain  more_than_one_chiral_center  \
# 8                     False         False                        False
# 11                    False         False                        False
# 38                    False         False                        False
# 85                    False         False                        False
# 105                   False         False                        False
# ...                     ...           ...                          ...
# 61887                 False         False                        False
# 61899                 False         False                        False
# 61913                 False         False                        False
# 61914                 False         False                        False
# 62482                 False         False                        False
#
#        too_many_pcores  satisfies_ro5
# 8                False           True
# 11               False           True
# 38               False           True
# 85               False           True
# 105              False           True
# ...                ...            ...
# 61887            False           True
# 61899            False           True
# 61913            False           True
# 61914            False           True
# 62482            False           True
#
# [1832 rows x 11 columns]

# %%
from rdkit.Chem import Lipinski, Descriptors

df_isocyanides['logP'] = df_isocyanides['mol'].progress_apply(
    Descriptors.MolLogP)

# %%
from rdkit.Chem import MolFromSmiles

best_ugi_mol = 'CC(C)Oc1ccc(cc1)N(C(C(=O)NCCc1ccns1)c1cccnc1)C(=O)c1cocn1'
print(Descriptors.MolLogP(MolFromSmiles(best_ugi_mol)))
print(does_mol_satisfy_ro5(best_ugi_mol))
# Out:
# 4.0603000000000025
# True

# %%
df_filtered[['ID', 'SMILES', 'ugi', 'predicted_pIC50']].sort_values(by='predicted_pIC50', ascending=False).to_csv(
    '/rds-d2/user/wjm41/hpc-work/datasets/Ugis/datasets/enamine_library_generation/enumerated_isocyanides_filtered.csv', index=False)
df_isocyanides.drop(columns=['mol', 'Error']).to_csv(
    '/rds-d2/user/wjm41/hpc-work/datasets/Ugis/datasets/enamine_library_generation/enumerated_isocyanides_scored.csv', index=False)

# %%
import mols2grid

df_view = df_isocyanides.query(
    '~more_than_one_chiral_center & ~matches_pain & ~has_structural_alert & satisfies_ro5').drop_duplicates('ugi')

best_mols = df_view.nlargest(100, 'predicted_pIC50')
mols2grid.display(best_mols,
                  smiles_col='ugi',
                  subset=['img', 'predicted_pIC50', 'logP'],
                  transform={
                      'predicted_pIC50': lambda x: f'Predicted pIC50: {x:.3f}',
                      'logP': lambda x: f'LogP: {x:.3f}'},
                  size=(300, 300),
                  width=2000)
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="2000"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 1520px;
#     width: 1520px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 300px;
#     width: 300px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# #mols2grid .data {
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
#     display: block;
# }
# #mols2grid .arrow-asc:after {
#     content: &#x27;↑&#x27;;
#     text-align: right;
#     float:right;
# }
# #mols2grid .arrow-desc:after {
#     content: &#x27;↓&#x27;;
#     text-align: right;
#     float:right;
# }
#     /* custom CSS */
#
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
# &lt;script src=&quot;https://code.jquery.com/jquery-3.6.0.min.js&quot; integrity=&quot;sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
# &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2022.3.1/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#     &lt;!-- custom header --&gt;
#
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer grid-default&quot;&gt;
#       &lt;div class=&quot;row mb-3&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left cached_checkbox&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-predicted_pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-logP&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-ugi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;d-inline&quot;&gt;
#         &lt;ul class=&quot;pagination float-left&quot;&gt;&lt;/ul&gt;
#         &lt;div id=&quot;controls&quot; class=&quot;d-flex flex-row float-right&quot;&gt;
#
#           &lt;div id=&quot;chkbox-dropdown&quot; class=&quot;dropdown&quot;&gt;
#     &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;chkboxDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;☑&lt;/button&gt;
#     &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;checkboxDropdownMenu&quot;&gt;
#         &lt;button id=&quot;btn-chkbox-all&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Check all&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-match&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Check matching&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-none&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Uncheck all&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-invert&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Invert&lt;/button&gt;
#         &lt;div class=&quot;dropdown-divider&quot;&gt;&lt;/div&gt;
#         &lt;button id=&quot;btn-chkbox-copy&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Copy to clipboard&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-dlsmi&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Save SMILES&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-dlcsv&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Save CSV&lt;/button&gt;
#     &lt;/div&gt;
# &lt;/div&gt;
#
#           &lt;div id=&quot;sort-dropdown&quot; class=&quot;dropdown pl-2&quot;&gt;
#             &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#               Sort by
#             &lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn &quot; type=&quot;button&quot; data-name=&quot;data-predicted_pIC50&quot;&gt;predicted_pIC50&lt;/button&gt;
#
#
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn &quot; type=&quot;button&quot; data-name=&quot;data-logP&quot;&gt;logP&lt;/button&gt;
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;checkbox&quot;&gt;Selected&lt;/button&gt;
#
#             &lt;/div&gt;
#           &lt;/div&gt;
#           &lt;div class=&quot;input-group row pl-4&quot;&gt;
#             &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#             &lt;div class=&quot;input-group-append&quot;&gt;
#               &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#               &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#                 &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#                 &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#               &lt;/div&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#     // list.js
# var listObj = new List(&#x27;mols2grid&#x27;, {
#     valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-ugi&#x27;, &#x27;data-img&#x27;, &#x27;data-logP&#x27;, &#x27;data-predicted_pIC50&#x27;],
#     item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left cached_checkbox&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-predicted_pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-logP&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-ugi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#     page: 15,
#     pagination: {
#         name: &quot;pagination&quot;,
#         item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&l

# %%
best_mols[['predicted_pIC50', 'logP']] = best_mols[['predicted_pIC50', 'logP']].round(3)

# %%
best_mols[['ID', 'SMILES', 'ugi', 'predicted_pIC50', 'logP']].to_csv(
    '/rds-d2/user/wjm41/hpc-work/datasets/Ugis/datasets/enamine_library_generation/enumerated_isocyanide_library/top_100.csv', index=False)

# %%
df_view = df_isocyanides.query('~more_than_one_chiral_center & logP < 5.1')

best_mols = df_view.nlargest(100, 'predicted_pIC50')
best_mols.iloc[:11]
# Out:
#               ID                     SMILES  \
# 3    EN300-61594            CCNc1cccc(CO)c1
# 4   EN300-100942               CCCNc1cccnc1
# 8    EN300-75265                CCNc1ccncc1
# 9   EN300-174170             CCNc1cccc(O)c1
# 11   EN300-19067              COc1cccc(N)c1
# 16   EN300-53053             Nc1ccc(CCO)cc1
# 19  EN300-248914             Nc1cccc(CCO)c1
# 21  EN300-120383              COc1ccnc(N)c1
# 30   EN300-61358  Nc1cccc(C(=O)Nc2cnccn2)c1
# 36  EN300-385266           Cl.Cl.NCCc1ccns1
# 37  EN300-373578              Cl.NCCc1ccns1
#
#                                                   ugi  predicted_pIC50  \
# 3   CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.528175
# 4   CCCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C...         5.518613
# 8   CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.494262
# 9   CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.494060
# 11  COc1cccc(NC(=O)C(c2cccnc2)N(C(=O)c2cocn2)c2ccc...         5.476997
# 16  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)Nc2ccc(CCO)c...         5.466761
# 19  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)Nc2cccc(CCO)...         5.461609
# 21  COc1ccnc(NC(=O)C(c2cccnc2)N(C(=O)c2cocn2)c2ccc...         5.454452
# 30  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)Nc2cccc(C(=O...         5.430921
# 36  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)NCCc2ccns2)c...         5.420857
# 37  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)NCCc2ccns2)c...         5.420857
#
#                                                  mol Error  \
# 3   <rdkit.Chem.rdchem.Mol object at 0x151acd92a8e0>
# 4   <rdkit.Chem.rdchem.Mol object at 0x151acd92a4c0>
# 8   <rdkit.Chem.rdchem.Mol object at 0x151acd92a5e0>
# 9   <rdkit.Chem.rdchem.Mol object at 0x151acd92a3a0>
# 11  <rdkit.Chem.rdchem.Mol object at 0x151acd92a9a0>
# 16  <rdkit.Chem.rdchem.Mol object at 0x151acd92ab80>
# 19  <rdkit.Chem.rdchem.Mol object at 0x151acd92aca0>
# 21  <rdkit.Chem.rdchem.Mol object at 0x151acd92ad60>
# 30  <rdkit.Chem.rdchem.Mol object at 0x151acd1f8100>
# 36  <rdkit.Chem.rdchem.Mol object at 0x151acd1f8340>
# 37  <rdkit.Chem.rdchem.Mol object at 0x151acd1f83a0>
#
#     has_structural_alert  matches_pain  more_than_one_chiral_center  \
# 3                  False         False                        False
# 4                  False         False                        False
# 8                  False         False                        False
# 9                   True         False                        False
# 11                 False         False                        False
# 16                 False         False                        False
# 19                 False         False                        False
# 21                 False         False                        False
# 30                 False         False                        False
# 36                 False         False                        False
# 37                 False         False                        False
#
#     too_many_pcores  satisfies_ro5    logP
# 3             False          False  4.7903
# 4             False          False  5.0831
# 8             False           True  4.6930
# 9             False          False  5.0036
# 11            False           True  4.8922
# 16             True          False  4.4184
# 19             True          False  4.4184
# 21             True           True  4.2872
# 30             True          False  4.9259
# 36             True           True  4.0603
# 37             True           True  4.0603

# %%
df_view = df_isocyanides.query(
    '~more_than_one_chiral_center & ~matches_pain & ~has_structural_alert & ~too_many_pcores & logP < 5.1').nlargest(100, 'predicted_pIC50').iloc[:10]
df_view
# Out:
#               ID               SMILES  \
# 3    EN300-61594      CCNc1cccc(CO)c1
# 4   EN300-100942         CCCNc1cccnc1
# 8    EN300-75265          CCNc1ccncc1
# 11   EN300-19067        COc1cccc(N)c1
# 38   EN300-20183       N#Cc1cccc(N)c1
# 46  EN300-106670     OCCNc1ccc(Br)cc1
# 65  EN300-107394      NCCc1ccc(Cl)nc1
# 82  EN300-137644  NCCc1ccc2[nH]ccc2c1
# 85  EN300-180531       CCC(C)(C)CN.Cl
# 91   EN300-76663        COCCNc1ccncc1
#
#                                                   ugi  predicted_pIC50  \
# 3   CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.528175
# 4   CCCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C...         5.518613
# 8   CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.494262
# 11  COc1cccc(NC(=O)C(c2cccnc2)N(C(=O)c2cocn2)c2ccc...         5.476997
# 38  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)Nc2cccc(C#N)...         5.420334
# 46  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N(CCO)c2ccc(...         5.405484
# 65  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)NCCc2ccc(Cl)...         5.390312
# 82  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)NCCc2ccc3[nH...         5.380320
# 85  CCC(C)(C)CNC(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1cc...         5.379709
# 91  COCCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(...         5.376807
#
#                                                  mol Error  \
# 3   <rdkit.Chem.rdchem.Mol object at 0x151acd92a8e0>
# 4   <rdkit.Chem.rdchem.Mol object at 0x151acd92a4c0>
# 8   <rdkit.Chem.rdchem.Mol object at 0x151acd92a5e0>
# 11  <rdkit.Chem.rdchem.Mol object at 0x151acd92a9a0>
# 38  <rdkit.Chem.rdchem.Mol object at 0x151acd1f8400>
# 46  <rdkit.Chem.rdchem.Mol object at 0x151acd1f8700>
# 65  <rdkit.Chem.rdchem.Mol object at 0x151acd1f8e20>
# 82  <rdkit.Chem.rdchem.Mol object at 0x151acd1f94c0>
# 85  <rdkit.Chem.rdchem.Mol object at 0x151acd1f95e0>
# 91  <rdkit.Chem.rdchem.Mol object at 0x151acd1f9820>
#
#     has_structural_alert  matches_pain  more_than_one_chiral_center  \
# 3                  False         False                        False
# 4                  False         False                        False
# 8                  False         False                        False
# 11                 False         False                        False
# 38                 False         False                        False
# 46                 False         False                        False
# 65                 False         False                        False
# 82                 False         False                        False
# 85                 False         False                        False
# 91                 False         False                        False
#
#     too_many_pcores  satisfies_ro5     logP
# 3             False          False  4.79030
# 4             False          False  5.08310
# 8             False           True  4.69300
# 11            False           True  4.89220
# 38            False           True  4.75528
# 46            False          False  5.03290
# 65            False          False  4.65220
# 82            False          False  5.08510
# 85            False           True  4.79730
# 91            False          False  4.31950

# %%
df_view = df_isocyanides.query(
    '~more_than_one_chiral_center & ~matches_pain & ~has_structural_alert & ~too_many_pcores & logP < 5.1').drop_duplicates('ugi').sort_values(by='predicted_pIC50', ascending=False)
df_view
# Out:
#                    ID                             SMILES  \
# 0         EN300-61594                    CCNc1cccc(CO)c1
# 2        EN300-100942                       CCCNc1cccnc1
# 10        EN300-75265                        CCNc1ccncc1
# 24        EN300-68689  CC(C)(C)c1nc2cc(N)ccc2[nH]1.Cl.Cl
# 27        EN300-19067                      COc1cccc(N)c1
# ...               ...                                ...
# 62615     EN300-55249                 CCOc1cccc(C(C)N)c1
# 62629  EN300-28256540       Cc1ncc(F)c(C2CCNCC2)n1.Cl.Cl
# 62660     EN300-33484              Nc1cccc(Cl)c1-n1cncn1
# 62718    EN300-359669              Cc1cc(C)n(C2CCNCC2)n1
# 62779  EN300-27780519           Cl.Cn1cc(F)c(C2CCNCC2)n1
#
#                                                      ugi  predicted_pIC50  \
# 0      CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.552310
# 2      CCCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C...         5.492673
# 10     CCN(C(=O)C(c1cccnc1)N(C(=O)c1cocn1)c1ccc(OC(C)...         5.435981
# 24     CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N(CCO)c2ccc(...         5.399508
# 27     COc1cccc(NC(=O)C(c2cccnc2)N(C(=O)c2cocn2)c2ccc...         5.391374
# ...                                                  ...              ...
# 62615  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N2CCN(C)c3cc...         4.159684
# 62629  Cc1ncc(F)c(C2CCN(C(=O)C(c3cccnc3)N(C(=O)c3cocn...         4.158195
# 62660  Cc1cc(C)n(CC2CCN(C(=O)C(c3cccnc3)N(C(=O)c3cocn...         4.155576
# 62718  Cc1cc(C)n(C2CCN(C(=O)C(c3cccnc3)N(C(=O)c3cocn3...         4.149045
# 62779  CC(C)Oc1ccc(N(C(=O)c2cocn2)C(C(=O)N2CCC(c3nn(C...         4.134556
#
#        has_structural_alert  matches_pain  more_than_one_chiral_center  \
# 0                     False         False                        False
# 2                     False         False                        False
# 10                    False         False                        False
# 24                    False         False                        False
# 27                    False         False                        False
# ...                     ...           ...                          ...
# 62615                 False         False                        False
# 62629                 False         False                        False
# 62660                 False         False                        False
# 62718                 False         False                        False
# 62779                 False         False                        False
#
#        too_many_pcores  satisfies_ro5  \
# 0                False          False
# 2                False          False
# 10               False           True
# 24               False          False
# 27               False           True
# ...                ...            ...
# 62615            False          False
# 62629            False          False
# 62660            False          False
# 62718            False          False
# 62779            False          False
#
#                                                     mol Error     logP
# 0      <rdkit.Chem.rdchem.Mol object at 0x150296e3e220>        4.79030
# 2      <rdkit.Chem.rdchem.Mol object at 0x150296e3e100>        5.08310
# 10     <rdkit.Chem.rdchem.Mol object at 0x150296e3e7c0>        4.69300
# 24     <rdkit.Chem.rdchem.Mol object at 0x150296e3efa0>        5.03290
# 27     <rdkit.Chem.rdchem.Mol object at 0x150299eb2100>        4.89220
# ...                                                 ...   ...      ...
# 62615  <rdkit.Chem.rdchem.Mol object at 0x1502994e2f40>        4.86700
# 62629  <rdkit.Chem.rdchem.Mol object at 0x1502994e44c0>        4.88862
# 62660  <rdkit.Chem.rdchem.Mol object at 0x1502994e60a0>        4.99704
# 62718  <rdkit.Chem.rdchem.Mol object at 0x1502994e76a0>        4.92194
# 62779  <rdkit.Chem.rdchem.Mol object at 0x1502994e9dc0>        4.52370
#
# [4427 rows x 12 columns]

# %%
mols2grid.display(df_view.nlargest(20, 'predicted_pIC50'),
                  smiles_col='ugi',
                  subset=['img', 'predicted_pIC50', 'logP'],
                  transform={
                      'predicted_pIC50': lambda x: f'Predicted pIC50: {x:.3f}',
                      'logP': lambda x: f'LogP: {x:.3f}'},
                  size=(300, 300),
                  width=2000)
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="2000"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 1520px;
#     width: 1520px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 300px;
#     width: 300px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# #mols2grid .data {
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
#     display: block;
# }
# #mols2grid .arrow-asc:after {
#     content: &#x27;↑&#x27;;
#     text-align: right;
#     float:right;
# }
# #mols2grid .arrow-desc:after {
#     content: &#x27;↓&#x27;;
#     text-align: right;
#     float:right;
# }
#     /* custom CSS */
#
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
# &lt;script src=&quot;https://code.jquery.com/jquery-3.6.0.min.js&quot; integrity=&quot;sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
# &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2022.3.1/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#     &lt;!-- custom header --&gt;
#
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer grid-default&quot;&gt;
#       &lt;div class=&quot;row mb-3&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left cached_checkbox&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-predicted_pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-logP&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-ugi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;d-inline&quot;&gt;
#         &lt;ul class=&quot;pagination float-left&quot;&gt;&lt;/ul&gt;
#         &lt;div id=&quot;controls&quot; class=&quot;d-flex flex-row float-right&quot;&gt;
#
#           &lt;div id=&quot;chkbox-dropdown&quot; class=&quot;dropdown&quot;&gt;
#     &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;chkboxDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;☑&lt;/button&gt;
#     &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;checkboxDropdownMenu&quot;&gt;
#         &lt;button id=&quot;btn-chkbox-all&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Check all&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-match&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Check matching&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-none&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Uncheck all&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-invert&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Invert&lt;/button&gt;
#         &lt;div class=&quot;dropdown-divider&quot;&gt;&lt;/div&gt;
#         &lt;button id=&quot;btn-chkbox-copy&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Copy to clipboard&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-dlsmi&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Save SMILES&lt;/button&gt;
#         &lt;button id=&quot;btn-chkbox-dlcsv&quot; class=&quot;dropdown-item&quot; type=&quot;button&quot;&gt;Save CSV&lt;/button&gt;
#     &lt;/div&gt;
# &lt;/div&gt;
#
#           &lt;div id=&quot;sort-dropdown&quot; class=&quot;dropdown pl-2&quot;&gt;
#             &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#               Sort by
#             &lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn &quot; type=&quot;button&quot; data-name=&quot;data-predicted_pIC50&quot;&gt;predicted_pIC50&lt;/button&gt;
#
#
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn &quot; type=&quot;button&quot; data-name=&quot;data-logP&quot;&gt;logP&lt;/button&gt;
#
#
#
#               &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;checkbox&quot;&gt;Selected&lt;/button&gt;
#
#             &lt;/div&gt;
#           &lt;/div&gt;
#           &lt;div class=&quot;input-group row pl-4&quot;&gt;
#             &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#             &lt;div class=&quot;input-group-append&quot;&gt;
#               &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#               &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#                 &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#                 &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#               &lt;/div&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#     // list.js
# var listObj = new List(&#x27;mols2grid&#x27;, {
#     valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-ugi&#x27;, &#x27;data-predicted_pIC50&#x27;, &#x27;data-img&#x27;, &#x27;data-logP&#x27;],
#     item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left cached_checkbox&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-predicted_pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-logP&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-ugi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#     page: 15,
#     pagination: {
#         name: &quot;pagination&quot;,
#         item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&l
